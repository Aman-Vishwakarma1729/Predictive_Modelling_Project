# %% [markdown]
# ## Problem 1

# %%
## Importing required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Reading Dataset

data1 = pd.read_excel('/content/drive/MyDrive/Project-5/compactiv.xlsx')

# %%
print(f"The compactive dataset have {data1.shape[0]} rows and {data1.shape[1]} columns")
print(f"The  compactive dataset contains {data1.size} data points")
# Out:
# The compactive dataset have 8192 rows and 22 columns
# The  compactive dataset contains 180224 data points

# %%
## First 10 entries of data

data1.head(10)
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec    rchar     wchar  pgout  \
# 0      1       0   2147     79      68   0.2   0.2  40671.0   53995.0    0.0
# 1      0       0    170     18      21   0.2   0.2    448.0    8385.0    0.0
# 2     15       3   2162    159     119   2.0   2.4      NaN   31950.0    0.0
# 3      0       0    160     12      16   0.2   0.2      NaN    8670.0    0.0
# 4      5       1    330     39      38   0.4   0.4      NaN   12185.0    0.0
# 5      0       0   1201     65      61   0.4   0.4      NaN   58703.0    0.0
# 6      1       0   5744    168     190   0.2   0.2      NaN  189975.0    6.0
# 7     21      18   2799    291     211   0.6   0.4      NaN  259868.0    2.6
# 8      0       0    264     42      33   0.2   0.2      NaN   10116.0    0.0
# 9      0       0    188     13      24   0.2   0.2      NaN    6777.0    0.0
#
#    ...  pgscan  atch  pgin  ppgin    pflt    vflt         runqsz  freemem  \
# ...

# %%
## Last 10 entries of data

data1.tail(10)
# Out:
#       lread  lwrite  scall  sread  swrite   fork   exec     rchar     wchar  \
# 8182     10       0   5975    692     612   2.20   2.00  505718.0  475455.0
# 8183      4       3   1509    501     139   0.60   1.00  312242.0  255308.0
# 8184      8       2   4784    416     240   1.20   1.60  442876.0  110453.0
# 8185     13       0   4279    235     176  12.22  34.47  289309.0   30701.0
# 8186      0       0    300     56      46   0.20   0.20    1995.0   18052.0
# 8187     16      12   3009    360     244   1.60   5.81  405250.0   85282.0
# 8188      4       0   1596    170     146   2.40   1.80   89489.0   41764.0
# 8189     16       5   3116    289     190   0.60   0.60  325948.0   52640.0
# 8190     32      45   5180    254     179   1.20   1.20   62571.0   29505.0
# 8191      2       0    985     55      46   1.60   4.80  111111.0   22256.0
#
#       pgout  ...  pgscan  atch   pgin  ppgin    pflt    vflt         runqsz  \
# ...

# %%
print(f"The columns of compactiv dataset are:\n {data1.columns}")
# Out:
# The columns of compactiv dataset are:
#  Index(['lread', 'lwrite', 'scall', 'sread', 'swrite', 'fork', 'exec', 'rchar',
#        'wchar', 'pgout', 'ppgout', 'pgfree', 'pgscan', 'atch', 'pgin', 'ppgin',
#        'pflt', 'vflt', 'runqsz', 'freemem', 'freeswap', 'usr'],
#       dtype='object')

# %% [markdown]
# ## Description about each column
#
# * lread - Reads (transfers per second ) between system memory and user memory
# * lwrite - writes (transfers per second) between system memory and user memory
# * scall - Number of system calls of all types per second
# * sread - Number of system read calls per second.
# * swrite - Number of system write calls per second.
# * fork - Number of system fork calls per second.
# * exec - Number of system exec calls per second.
# * rchar - Number of characters transferred per second by system read calls
# * wchar - Number of characters transfreed per second by system write calls
# * pgout - Number of page out requests per second
# * ppgout - Number of pages, paged out per second
# * pgfree - Number of pages per second placed on the free list.
# * pgscan - Number of pages checked if they can be freed per second
# * atch - Number of page attaches (satisfying a page fault by reclaiming a page in memory) per second
# * pgin - Number of page-in requests per second
# * ppgin - Number of pages paged in per second
# * pflt - Number of page faults caused by protection errors (copy-on-writes).
# * vflt - Number of page faults caused by address translation .
# * runqsz - Process run queue size (The number of kernel threads in memory that are waiting for a CPU to run.
# * Typically, this value should be less than 2. Consistently higher values mean that the system might be CPU-bound.)
# * freemem - Number of memory pages available to user processes
# * freeswap - Number of disk blocks available for page swapping

# %%
## Getting basic statistics of data

data1.describe().T
# Out:
#            count          mean            std     min        25%        50%  \
# lread     8192.0  1.955969e+01      53.353799     0.0        2.0        7.0
# lwrite    8192.0  1.310620e+01      29.891726     0.0        0.0        1.0
# scall     8192.0  2.306318e+03    1633.617322   109.0     1012.0     2051.5
# sread     8192.0  2.104800e+02     198.980146     6.0       86.0      166.0
# swrite    8192.0  1.500582e+02     160.478980     7.0       63.0      117.0
# fork      8192.0  1.884554e+00       2.479493     0.0        0.4        0.8
# exec      8192.0  2.791998e+00       5.212456     0.0        0.2        1.2
# rchar     8088.0  1.973857e+05  239837.493526   278.0    34091.5   125473.5
# wchar     8177.0  9.590299e+04  140841.707911  1498.0    22916.0    46619.0
# pgout     8192.0  2.285317e+00       5.307038     0.0        0.0        0.0
# ppgout    8192.0  5.977229e+00      15.214590     0.0        0.0        0.0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lread     8192 non-null   int64
#  1   lwrite    8192 non-null   int64
#  2   scall     8192 non-null   int64
#  3   sread     8192 non-null   int64
#  4   swrite    8192 non-null   int64
#  5   fork      8192 non-null   float64
#  6   exec      8192 non-null   float64
#  7   rchar     8088 non-null   float64
#  8   wchar     8177 non-null   float64
#  9   pgout     8192 non-null   float64
#  10  ppgout    8192 non-null   float64
#  11  pgfree    8192 non-null   float64
#  12  pgscan    8192 non-null   float64
#  13  atch      8192 non-null   float64
#  14  pgin      8192 non-null   float64
#  15  ppgin     8192 non-null   float64
#  16  pflt      8192 non-null   float64
#  17  vflt      8192 non-null   float64
#  18  runqsz    8192 non-null   object
#  19  freemem   8192 non-null   int64
# ...

# %% [markdown]
# * There are 3 types of data format present in compactive dataset.
# * >> int64 (8 columns)
# * >> flaot64 (13 columns)
# * >> object (1 column)
# * The dataset occupies 1.4+ MB of memory space
# * There are missing values in compactive dataset

# %%
## Getting numbers of null values in dataset

data1.isnull().sum()
# Out:
# lread         0
# lwrite        0
# scall         0
# sread         0
# swrite        0
# fork          0
# exec          0
# rchar       104
# wchar        15
# pgout         0
# ppgout        0
# pgfree        0
# pgscan        0
# atch          0
# pgin          0
# ppgin         0
# pflt          0
# vflt          0
# runqsz        0
# freemem       0
# freeswap      0
# usr           0
# dtype: int64

# %% [markdown]
# * There are 104 missing values in "rchar" column.
# * There are 15 missing values in "wchar" column.

# %%
## Looking for duplicate values

data1[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [lread, lwrite, scall, sread, swrite, fork, exec, rchar, wchar, pgout, ppgout, pgfree, pgscan, atch, pgin, ppgin, pflt, vflt, runqsz, freemem, freeswap, usr]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# * There is no duplicated values in compactive dataset.

# %%
data1['runqsz'].value_counts()
# Out:
# Not_CPU_Bound    4331
# CPU_Bound        3861
# Name: runqsz, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.title('Pie chart for "runqsz" column')
plt.pie(data1['runqsz'].value_counts(),labels=data1['runqsz'].unique(),autopct='%1f')
plt.show()

# %% [markdown]
# * The compactive dataset is almost balanced dataset

# %%
## Checking out the distribution of data in numerical columns

numerical_columns = data1.drop(columns='runqsz')
fig,axes = plt.subplots(nrows=7,ncols=3,figsize=(20,20))
fig.subplots_adjust(hspace=0.5)
axes = axes.flatten()
for i,column in enumerate(numerical_columns.columns):
  ax = axes[i]
  sns.histplot(numerical_columns[column], ax=ax, kde=True)
  ax.set_title(f'Distribution of {column}')
  ax.set_xlabel(column)
  ax.set_ylabel('Frequency')

# %%
## looking at boxplot of data in numerical columns

numerical_columns = data1.drop(columns='runqsz')
fig,axes = plt.subplots(nrows=7,ncols=3,figsize=(13,20))
fig.subplots_adjust(hspace=0.5)
axes = axes.flatten()
for i,column in enumerate(numerical_columns.columns):
  ax = axes[i]
  sns.boxplot(numerical_columns[column], ax=ax)
  ax.set_title(f'Distribution of {column}')
  ax.set_xlabel(column)
  ax.set_ylabel('Frequency')

# %% [markdown]
# * We can observe from above box plots that almost every column have outliers

# %%
plt.figure(figsize=(15,12))
sns.heatmap(numerical_columns.corr(),annot=True)
plt.show()

# %% [markdown]
# * Here we can understand the correlation between each feature.
# * value in (-0.25,0) or (0,0.25) --> Weak correltion between features.
# * value in (-0.75,-0.25) or (0.25,0.75) --> intermediate correltion between features.
# * value in (-1,-0.75) or (0.75,1) --> strong correltion between features.

# %%
## Checking out bar graph between categrical and numrecical featurs.

numerical_columns = data1.drop(columns='runqsz')
fig,axes = plt.subplots(nrows=7,ncols=3,figsize=(20,20))
fig.subplots_adjust(hspace=0.5)
axes = axes.flatten()
for i,column in enumerate(numerical_columns.columns):
  ax = axes[i]
  sns.barplot(x=data1['runqsz'], y=numerical_columns[column], ax=ax)
  ax.set_title(f'Distribution of {column}')
  ax.set_xlabel(column)
  ax.set_ylabel('Frequency')

# %% [markdown]
# ## Handling null values

# %% [markdown]
# * There are 104 missing values in "rchar" column.
# * There are 15 missing values in "wchar" column.
# * And since both columns have outliers we will used median value of respective columns to fill the missing values.

# %%
data1['rchar'].fillna(data1['rchar'].median(),inplace=True)
data1['wchar'].fillna(data1['wchar'].median(),inplace=True)

# %%
data1.isnull().sum()
# Out:
# lread       0
# lwrite      0
# scall       0
# sread       0
# swrite      0
# fork        0
# exec        0
# rchar       0
# wchar       0
# pgout       0
# ppgout      0
# pgfree      0
# pgscan      0
# atch        0
# pgin        0
# ppgin       0
# pflt        0
# vflt        0
# runqsz      0
# freemem     0
# freeswap    0
# usr         0
# dtype: int64

# %%
data1
# Out:
#       lread  lwrite  scall  sread  swrite  fork  exec     rchar    wchar  \
# 0         1       0   2147     79      68   0.2  0.20   40671.0  53995.0
# 1         0       0    170     18      21   0.2  0.20     448.0   8385.0
# 2        15       3   2162    159     119   2.0  2.40  125473.5  31950.0
# 3         0       0    160     12      16   0.2  0.20  125473.5   8670.0
# 4         5       1    330     39      38   0.4  0.40  125473.5  12185.0
# ...     ...     ...    ...    ...     ...   ...   ...       ...      ...
# 8187     16      12   3009    360     244   1.6  5.81  405250.0  85282.0
# 8188      4       0   1596    170     146   2.4  1.80   89489.0  41764.0
# 8189     16       5   3116    289     190   0.6  0.60  325948.0  52640.0
# 8190     32      45   5180    254     179   1.2  1.20   62571.0  29505.0
# 8191      2       0    985     55      46   1.6  4.80  111111.0  22256.0
#
#       pgout  ...  pgscan  atch   pgin  ppgin    pflt    vflt         runqsz  \
# ...

# %%
for column in data1.columns:
    zero_count = data1[data1[column] == 0][column].size
    print(f'There are {zero_count} zeros in {column} column')
# Out:
# There are 675 zeros in lread column
# There are 2684 zeros in lwrite column
# There are 0 zeros in scall column
# There are 0 zeros in sread column
# There are 0 zeros in swrite column
# There are 21 zeros in fork column
# There are 21 zeros in exec column
# There are 0 zeros in rchar column
# There are 0 zeros in wchar column
# There are 4878 zeros in pgout column
# There are 4878 zeros in ppgout column
# There are 4869 zeros in pgfree column
# There are 6448 zeros in pgscan column
# There are 4575 zeros in atch column
# There are 1220 zeros in pgin column
# There are 1220 zeros in ppgin column
# There are 3 zeros in pflt column
# There are 0 zeros in vflt column
# There are 0 zeros in runqsz column
# There are 0 zeros in freemem column
# There are 0 zeros in freeswap column
# There are 283 zeros in usr column

# %% [markdown]
# * We can keep the Zero's in our dataset for further analysis as we have some features in our datase twhich can be Zero if the system stays is not performing any task.

# %% [markdown]
# ## Handling categorical variable.
# * From above analysis we can see that we have only one categorical features i.e "runqsz" it has two categories.
# >> CPU_Bound
# >> Not_CPU_Bound
# * We will encode it as:
# >> *  CPU_Bound : 1
# >> *  Not_CPU_Bound : 0

# %%
data1['runqsz'] = [1 if i == "CPU_Bound" else 0 for i in data1['runqsz'] ]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lread     8192 non-null   int64
#  1   lwrite    8192 non-null   int64
#  2   scall     8192 non-null   int64
#  3   sread     8192 non-null   int64
#  4   swrite    8192 non-null   int64
#  5   fork      8192 non-null   float64
#  6   exec      8192 non-null   float64
#  7   rchar     8192 non-null   float64
#  8   wchar     8192 non-null   float64
#  9   pgout     8192 non-null   float64
#  10  ppgout    8192 non-null   float64
#  11  pgfree    8192 non-null   float64
#  12  pgscan    8192 non-null   float64
#  13  atch      8192 non-null   float64
#  14  pgin      8192 non-null   float64
#  15  ppgin     8192 non-null   float64
#  16  pflt      8192 non-null   float64
#  17  vflt      8192 non-null   float64
#  18  runqsz    8192 non-null   int64
#  19  freemem   8192 non-null   int64
# ...

# %%
## Dividing dataset in Dependent and Independent variables

X = data1.drop(columns="usr")    ## Independent variables
y = data1['usr']                 ## Dependent variables

# %%
## Spliting dataset as train test set.

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
## Trainig and Testing models

# %%
from sklearn.linear_model import LinearRegression
LR_model1 = LinearRegression()

# %%
LR_model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted_model1 = LR_model1.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_predicted_model1)
Rmse = mse**0.5
r_sqr = r2_score(y_test,y_predicted_model1)
print(f"Mean squared error for model1 is {mse}\nRoot mean squared error is {Rmse}\nR_square is {r_sqr}")
# Out:
# Mean squared error for model1 is 127.3430133193658
# Root mean squared error is 11.284636162471779
# R_square is 0.6406031458102

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X_train)
LRmodel2 = sm.OLS(y_train, X).fit()
print(LRmodel2.summary())
coefficients = LRmodel2.params
intercept = LRmodel2.params['const']
new_X = sm.add_constant(X_test)
predictions = LRmodel2.predict(new_X)
print("Coefficients:", coefficients)
print("Intercept:", intercept)
print("Predictions:", predictions)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    usr   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     480.9
# Date:                Sun, 24 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:48:22   Log-Likelihood:                -21859.
# No. Observations:                5734   AIC:                         4.376e+04
# Df Residuals:                    5712   BIC:                         4.391e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.0172      0.704     72.447      0.000      49.637      52.398
# ...

# %% [markdown]
# * From model-1 that is sci-kit Linear Regression we have r2_squared accuracy tov be: 64.06%
# * From model-2 that is stats-model Linear Regression we have r2_squared accuracy tov be: 63.9%
# * There we select model-1 for prediction.

# %% [markdown]
# ## Bussiness insights and recommendation
# * The model suggests that various independent variables have different impacts on the dependent variable 'usr'.
# * Focus on the statistically significant variables that have a meaningful impact on 'usr'.
# * For negatively correlated variables, consider strategies to optimize or reduce them if they are costly or undesirable.
# * For positively correlated variables, consider strategies to increase them if they are beneficial to your business.

# %% [markdown]
# ## Problem 2

# %%
data3 = pd.read_excel("/content/drive/MyDrive/Project-5/Contraceptive_method_dataset.xlsx")

# %%
data3
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0         24.0         Primary         Secondary                  3.0
# 1         45.0      Uneducated         Secondary                 10.0
# 2         43.0         Primary         Secondary                  7.0
# 3         42.0       Secondary           Primary                  9.0
# 4         36.0       Secondary         Secondary                  8.0
# ...        ...             ...               ...                  ...
# 1468      33.0        Tertiary          Tertiary                  NaN
# 1469      33.0        Tertiary          Tertiary                  NaN
# 1470      39.0       Secondary         Secondary                  NaN
# 1471      33.0       Secondary         Secondary                  NaN
# 1472      17.0       Secondary         Secondary                  1.0
#
#      Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# ...

# %%
print(f"The Contraceptive_method dataset have {data3.shape[0]} rows and {data3.shape[1]} columns")
print(f"The  Contraceptive_method dataset contains {data3.size} data points")
# Out:
# The Contraceptive_method dataset have 1473 rows and 10 columns
# The  Contraceptive_method dataset contains 14730 data points

# %%
data3.head(10)
# Out:
#    Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0      24.0         Primary         Secondary                  3.0
# 1      45.0      Uneducated         Secondary                 10.0
# 2      43.0         Primary         Secondary                  7.0
# 3      42.0       Secondary           Primary                  9.0
# 4      36.0       Secondary         Secondary                  8.0
# 5      19.0        Tertiary          Tertiary                  0.0
# 6      38.0         Primary         Secondary                  6.0
# 7      21.0       Secondary         Secondary                  1.0
# 8      27.0         Primary         Secondary                  3.0
# 9      45.0      Uneducated        Uneducated                  8.0
#
#   Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# 0   Scientology           No                   2                     High
# 1   Scientology           No                   3                Very High
# ...

# %%
data3.tail(10)
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 1463      30.0      Uneducated         Secondary                  NaN
# 1464      23.0         Primary           Primary                  NaN
# 1465      25.0         Primary          Tertiary                  NaN
# 1466      42.0         Primary          Tertiary                  NaN
# 1467      29.0        Tertiary          Tertiary                  NaN
# 1468      33.0        Tertiary          Tertiary                  NaN
# 1469      33.0        Tertiary          Tertiary                  NaN
# 1470      39.0       Secondary         Secondary                  NaN
# 1471      33.0       Secondary         Secondary                  NaN
# 1472      17.0       Secondary         Secondary                  1.0
#
#      Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# 1463   Scientology           No                   3                Very High
# ...

# %%
print(f"The columns of Contraceptive_method dataset are:\n {data3.columns}")
# Out:
# The columns of Contraceptive_method dataset are:
#  Index(['Wife_age', 'Wife_ education', 'Husband_education',
#        'No_of_children_born', 'Wife_religion', 'Wife_Working',
#        'Husband_Occupation', 'Standard_of_living_index', 'Media_exposure ',
#        'Contraceptive_method_used'],
#       dtype='object')

# %% [markdown]
# ## Description about each column of dataset.
# 1. Wife's age (numerical)
# 2. Wife's education (categorical) 1=uneducated, 2, 3, 4=tertiary
# 3. Husband's education (categorical) 1=uneducated, 2, 3, 4=tertiary
# 4. Number of children ever born (numerical)
# 5. Wife's religion (binary) Non-Scientology, Scientology
# 6. Wife's now working? (binary) Yes, No
# 7. Husband's occupation (categorical) 1, 2, 3, 4(random)
# 8. Standard-of-living index (categorical) 1=verlow, 2, 3, 4=high
# 9. Media exposure (binary) Good, Not good
# 10. Contraceptive method used (class attribute) No,Yes

# %%
data3.describe().T
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# Wife_age             1402.0  32.606277  8.274927  16.0  26.0  32.0  39.0  49.0
# No_of_children_born  1452.0   3.254132  2.365212   0.0   1.0   3.0   4.0  16.0
# Husband_Occupation   1473.0   2.137814  0.864857   1.0   1.0   2.0   3.0   4.0

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473 entries, 0 to 1472
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Wife_age                   1402 non-null   float64
#  1   Wife_ education            1473 non-null   object
#  2   Husband_education          1473 non-null   object
#  3   No_of_children_born        1452 non-null   float64
#  4   Wife_religion              1473 non-null   object
#  5   Wife_Working               1473 non-null   object
#  6   Husband_Occupation         1473 non-null   int64
#  7   Standard_of_living_index   1473 non-null   object
#  8   Media_exposure             1473 non-null   object
#  9   Contraceptive_method_used  1473 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 115.2+ KB

# %% [markdown]
# * There are 3 types of data present in given dataset.
# >> * int64 (1 column)
# >> * float64 (2 columns)
# >> * object (7 columns)
# * File size is 115.2+ KB
# * There are some missing values in "Wife_age" and "No_of_children_born" column

# %%
data3.isnull().sum()
# Out:
# Wife_age                     71
# Wife_ education               0
# Husband_education             0
# No_of_children_born          21
# Wife_religion                 0
# Wife_Working                  0
# Husband_Occupation            0
# Standard_of_living_index      0
# Media_exposure                0
# Contraceptive_method_used     0
# dtype: int64

# %% [markdown]
# * There are 71 missing values in "Wife_age" column.
# * There are 21 missing values in "No_of_children_born" column.

# %%
data3.duplicated().sum()
# Out:
# 80

# %% [markdown]
# * There are 80 duplicate values in given dataset.

# %%
## Dropping the duplicate values as it has no contribution in prediction.

data3.drop_duplicates(keep='first',inplace=True)

# %%
data3.duplicated().sum()
# Out:
# 0

# %%
data3.shape
# Out:
# (1393, 10)

# %%
data3
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0         24.0         Primary         Secondary                  3.0
# 1         45.0      Uneducated         Secondary                 10.0
# 2         43.0         Primary         Secondary                  7.0
# 3         42.0       Secondary           Primary                  9.0
# 4         36.0       Secondary         Secondary                  8.0
# ...        ...             ...               ...                  ...
# 1468      33.0        Tertiary          Tertiary                  NaN
# 1469      33.0        Tertiary          Tertiary                  NaN
# 1470      39.0       Secondary         Secondary                  NaN
# 1471      33.0       Secondary         Secondary                  NaN
# 1472      17.0       Secondary         Secondary                  1.0
#
#      Wife_religion Wife_Working  Husband_Occupation Standard_of_living_index  \
# ...

# %%
## We will thge drop the missing values

data3.dropna(inplace=True)

# %%
data3.isnull().sum()
# Out:
# Wife_age                     0
# Wife_ education              0
# Husband_education            0
# No_of_children_born          0
# Wife_religion                0
# Wife_Working                 0
# Husband_Occupation           0
# Standard_of_living_index     0
# Media_exposure               0
# Contraceptive_method_used    0
# dtype: int64

# %%
data3.reset_index(drop=True,inplace=True)

# %%
data3
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0         24.0         Primary         Secondary                  3.0
# 1         45.0      Uneducated         Secondary                 10.0
# 2         43.0         Primary         Secondary                  7.0
# 3         42.0       Secondary           Primary                  9.0
# 4         36.0       Secondary         Secondary                  8.0
# ...        ...             ...               ...                  ...
# 1300      29.0       Secondary          Tertiary                  5.0
# 1301      32.0       Secondary         Secondary                  4.0
# 1302      30.0        Tertiary          Tertiary                  1.0
# 1303      37.0        Tertiary          Tertiary                  1.0
# 1304      17.0       Secondary         Secondary                  1.0
#
#         Wife_religion Wife_Working  Husband_Occupation  \
# 0         Scientology           No                   2
# ...

# %%
num_col = ["Wife_age","No_of_children_born","Husband_Occupation"]
cat_col = [col for col in data3.columns if col not in num_col]

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(20,20))
fig.subplots_adjust(hspace=0.5)
axes = axes.flatten()
for i,column in enumerate(num_col):
  ax = axes[i]
  sns.histplot(data3[column], ax=ax, kde=True)
  ax.set_title(f'Distribution of {column}')
  ax.set_xlabel(column)
  ax.set_ylabel('Frequency')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(13,20))
fig.subplots_adjust(hspace=0.5)
axes = axes.flatten()
for i,column in enumerate(num_col):
  ax = axes[i]
  sns.boxplot(data3[column], ax=ax)
  ax.set_title(f'Distribution of {column}')
  ax.set_xlabel(column)
  ax.set_ylabel('Frequency')

# %% [markdown]
# * There are few outliers in No_of_children columns

# %%
plt.figure(figsize=(15,12))
sns.heatmap(data3[num_col].corr(),annot=True)
plt.show()

# %% [markdown]
# * There is intermediate correlation between No_of_children and Wife_Age

# %%
for i in cat_col:
  counts = data3[i].value_counts()
  print(f"{i} has categories with counts as\n{counts}\n")
# Out:
# Wife_ education has categories with counts as
# Tertiary      479
# Secondary     378
# Primary       306
# Uneducated    142
# Name: Wife_ education, dtype: int64
#
# Husband_education has categories with counts as
# Tertiary      778
# Secondary     322
# Primary       162
# Uneducated     43
# Name: Husband_education, dtype: int64
#
# Wife_religion has categories with counts as
# Scientology        1113
# Non-Scientology     192
# Name: Wife_religion, dtype: int64
#
# Wife_Working has categories with counts as
# No     976
# Yes    329
# Name: Wife_Working, dtype: int64
#
# Standard_of_living_index has categories with counts as
# Very High    571
# High         396
# Low          213
# Very Low     125
# Name: Standard_of_living_index, dtype: int64
#
# Media_exposure  has categories with counts as
# Exposed        1202
# Not-Exposed     103
# Name: Media_exposure , dtype: int64
#
# Contraceptive_method_used has categories with counts as
# Yes    691
# No     614
# ...

# %%
data3
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0         24.0         Primary         Secondary                  3.0
# 1         45.0      Uneducated         Secondary                 10.0
# 2         43.0         Primary         Secondary                  7.0
# 3         42.0       Secondary           Primary                  9.0
# 4         36.0       Secondary         Secondary                  8.0
# ...        ...             ...               ...                  ...
# 1300      29.0       Secondary          Tertiary                  5.0
# 1301      32.0       Secondary         Secondary                  4.0
# 1302      30.0        Tertiary          Tertiary                  1.0
# 1303      37.0        Tertiary          Tertiary                  1.0
# 1304      17.0       Secondary         Secondary                  1.0
#
#         Wife_religion Wife_Working  Husband_Occupation  \
# 0         Scientology           No                   2
# ...

# %%
## Encoding "Contraceptive_method_used" column.

data3['Contraceptive_method_used'] = [0 if  i == 'No' else 1 for i in data3['Contraceptive_method_used']]

# %%
data3
# Out:
#       Wife_age Wife_ education Husband_education  No_of_children_born  \
# 0         24.0         Primary         Secondary                  3.0
# 1         45.0      Uneducated         Secondary                 10.0
# 2         43.0         Primary         Secondary                  7.0
# 3         42.0       Secondary           Primary                  9.0
# 4         36.0       Secondary         Secondary                  8.0
# ...        ...             ...               ...                  ...
# 1300      29.0       Secondary          Tertiary                  5.0
# 1301      32.0       Secondary         Secondary                  4.0
# 1302      30.0        Tertiary          Tertiary                  1.0
# 1303      37.0        Tertiary          Tertiary                  1.0
# 1304      17.0       Secondary         Secondary                  1.0
#
#         Wife_religion Wife_Working  Husband_Occupation  \
# 0         Scientology           No                   2
# ...

# %%
X = data3.drop(columns='Contraceptive_method_used')
y = data3['Contraceptive_method_used']

# %%
# Encoding the categorical variables
cat_col = [col for col in X.columns if col not in num_col]
X = pd.get_dummies(X, columns=cat_col, drop_first=True)
X
# Out:
#       Wife_age  No_of_children_born  Husband_Occupation  \
# 0         24.0                  3.0                   2
# 1         45.0                 10.0                   3
# 2         43.0                  7.0                   3
# 3         42.0                  9.0                   3
# 4         36.0                  8.0                   3
# ...        ...                  ...                 ...
# 1300      29.0                  5.0                   3
# 1301      32.0                  4.0                   2
# 1302      30.0                  1.0                   3
# 1303      37.0                  1.0                   1
# 1304      17.0                  1.0                   2
#
#       Wife_ education_Secondary  Wife_ education_Tertiary  \
# 0                             0                         0
# 1                             0                         0
# 2                             0                         0
# ...

# %%
# Spliting the data into train and test sets.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
## Training and testing different  models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression()
lda = LinearDiscriminantAnalysis()
cart = DecisionTreeClassifier()

# %%
lr.fit(X_train, y_train)
lda.fit(X_train, y_train)
cart.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve

# %%
y_train_pred_lr = lr.predict(X_train)
y_test_pred_lr = lr.predict(X_test)
y_train_pred_lda = lda.predict(X_train)
y_test_pred_lda = lda.predict(X_test)
y_train_pred_cart = cart.predict(X_train)
y_test_pred_cart = cart.predict(X_test)

# %%
print("Logistic Regression Train Accuracy:", accuracy_score(y_train, y_train_pred_lr))
print("Logistic Regression Test Accuracy:", accuracy_score(y_test, y_test_pred_lr))
print("LDA Train Accuracy:", accuracy_score(y_train, y_train_pred_lda))
print("LDA Test Accuracy:", accuracy_score(y_test, y_test_pred_lda))
print("CART Train Accuracy:", accuracy_score(y_train, y_train_pred_cart))
print("CART Test Accuracy:", accuracy_score(y_test, y_test_pred_cart))

print("\nLogistic Regression Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_lr))
print("\nLDA Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_lda))
print("\nCART Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_cart))
# Out:
# Logistic Regression Train Accuracy: 0.6549835706462213
# Logistic Regression Test Accuracy: 0.6530612244897959
# LDA Train Accuracy: 0.6626506024096386
# LDA Test Accuracy: 0.6556122448979592
# CART Train Accuracy: 0.9879518072289156
# CART Test Accuracy: 0.6403061224489796
#
# Logistic Regression Confusion Matrix:
# [[ 98  79]
#  [ 57 158]]
#
# LDA Confusion Matrix:
# [[ 97  80]
#  [ 55 160]]
#
# CART Confusion Matrix:
# [[105  72]
#  [ 69 146]]

# %%
## Plotting ROC curve

fpr_lr, tpr_lr, _ = roc_curve(y_test, lr.predict_proba(X_test)[:,1])
fpr_lda, tpr_lda, _ = roc_curve(y_test, lda.predict_proba(X_test)[:,1])
fpr_cart, tpr_cart, _ = roc_curve(y_test, cart.predict_proba(X_test)[:,1])

plt.plot(fpr_lr, tpr_lr, label='Logistic Regression')
plt.plot(fpr_lda, tpr_lda)
